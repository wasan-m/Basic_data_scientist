# %% [markdown]
# # Basic Python
# * ภาษา Python เป็นภาษาโปรแกรมมิ่งที่เป็นที่นิยมในปัจจุบัน ใช้ในงาน Data Analytic, Data Science, Deep Learning, Web Development รวมไปถึงการ Automate Task ซึ่งช่วยประหยัดเวลาในการทำงานซ้ำๆได้

# %% [markdown]
# #Variable
# * ตัวแปรเปรียบเสมือนกล่องหรือ container ที่ใช้ในการเก็บข้อมูล
# * ชื่อตัวแปรที่ตั้งต้องเป็น Alpha-numeric (A-Z, 0-9 และ underscore _)
# * ตัวพิมพ์เล็กพิมพ์ใหญ่ มีค่าไม่เหมือนกัน (case sentitive)

# %%
my_height = 169

# %%
my_height
# Out:
# 169

# %%
my_height = 175

# %%
my_height
# Out:
# 175

# %%
22_name = 15
# Out:
#   File "<ipython-input-5-90be76a23c18>", line 1
#     22_name = 15
#       ^
# SyntaxError: invalid token

# %%
my_height_2020 = 170

# %%
my_height_2020
# Out:
# 170

# %%
#ความยาวด้านตรงข้ามมุมฉากของสามเหลี่ยมมุมฉาก
#length = np.sqrt(a^2+b^2)
import numpy as np
a = 3
b = 4
length = np.sqrt(a**2+b**2)

# %%
length
# Out:
# 5.0
