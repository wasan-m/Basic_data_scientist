# %% [markdown]
# # Introduction to Python
# Python Application
# * Web Development
#  * Flask, Django
# * Game Development
#  * PyGame
# * Scientific and Numeric Applications
#  * Pandas, Numpy, SciPy, NLTK
# * Artificial Intelligence and Machine Learning
#  * Tensorflow, Pytorch, Keras
# * Desktop GUI
#  * PyQt, Tkinter
# *  Web Scraping Applications
#  * BeautifulSoup, Selenium, Requests
# * Embedded Applications
#  * Raspberry Pi

# %% [markdown]
# ## Data Analytic and Data Science

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Web Framework

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## ตัวอย่างการใช้งาน Python ใน Tech Company

# %% [markdown]
# * TensorFlow เป็น open source library สำหรับพัฒนา Machine Learning ถูกพัฒนาโดยทีม Google Brain รองรับการใช้งานภาษา Python และ C++ https://www.youtube.com/watch?v=oZikw5k_2FM

# %% [markdown]
# * PyTorch เป็น Deep Learning Library ถูกพัฒนาโดยทีม Facebook AI Research (FAIR) https://www.youtube.com/watch?v=vkzr1xu-8Nk

# %% [markdown]
# * Instagram ใช้ django ซึ่งเป็น web framework ที่เขียนโดยใช้ python สามารถรองรับ user ได้หลายล้านคนต่อวัน https://instagram-engineering.com/web-service-efficiency-at-instagram-with-python-4976d078e366

# %% [markdown]
# ตัวอย่างการใช้งานโดย Tech Company อื่นๆ
# *  10 World-Class Companies Using Python https://towardsdatascience.com/10-world-class-companies-using-python-26cde24919a8
# * 6 Huge Tech Companies That Use Python: Does It Fit Your Project? https://ncube.com/blog/6-huge-tech-companies-that-use-python-does-it-fit-your-project

# %% [markdown]
# ## Web Scraping

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Raspberry Pi

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# * Make a Raspberry Pi Automated Gardener https://www.youtube.com/watch?v=51dg2MsYHns
# * Weekend Project: Home Automation with Raspberry Pi and OpenHab https://www.youtube.com/watch?v=G65aCy_SsYI
